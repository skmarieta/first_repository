# %% [markdown]
# <a href="https://colab.research.google.com/github/skmarieta/first_repository/blob/main/Work_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание №1

# %%
print('Hello word')
# Out:
# Hello word

# %% [markdown]
# Задание №2

# %%
print(4, 8, 15, 16, 23, 42, '°C')
# Out:
# 4 8 15 16 23 42 °C

# %% [markdown]
# Задание №3

# %%
for i in range(1,8):
  print(i*'*')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# Задание №4

# %%
print('Отчёт о доходах')
print('1 квартал: 1200000 руб.')
print('2 квартал: 1350000 руб.')
print('3 квартал: 1280000 руб.')
print('4 квартал: 1420000 руб.')
# Out:
# Отчёт о доходах
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.

# %% [markdown]
# Задание №5

# %%
name = input()
print('Добро пожаловать в команду,', name + '!')
# Out:
# Влад
# Добро пожаловать в команду, Влад!

# %% [markdown]
# Задание №6

# %%
name_company = input()
print(name_company, '- лидер рынка!')
# Out:
# Сбер
# Сбер - лидер рынка!

# %% [markdown]
# Задание №7

# %%
data_name = input()
row_count = input()
column_count = input()
print(data_name)
print(row_count)
print(column_count)
# Out:
# Sales Q1
# 1000
# 8
# Sales Q1
# 1000
# 8

# %% [markdown]
# Задание №8

# %%
report_1 = input()
report_2 = input()
report_3 = input()
print(report_3)
print(report_2)
print(report_1)
# Out:
# Продажи за январь
# Продажи за февраль
# Продажи за март
# Продажи за март
# Продажи за февраль
# Продажи за январь

# %% [markdown]
# Задание №9

# %%
base_price = int(input())
growth_percent = int(input())
new_price = base_price+base_price*growth_percent/100
delta = new_price-base_price
print('new_price =', new_price)
print ('delta =', delta)
# Out:
# 100
# 20
# new_price = 120.0
# delta = 20.0

# %% [markdown]
# Задание №10

# %%
print('Северный', 'Центральный','Южный', sep='***')
# Out:
# Северный***Центральный***Южный

# %% [markdown]
# Задание №11

# %%
name = input()
print('Подключение установлено.', end = ' ')
print('Добро пожаловать,', name + '!')
# Out:
# Влад
# Подключение установлено. Добро пожаловать, Влад!

# %% [markdown]
# Задание №12

# %%
sep_str = input()
product_1 = input()
product_2 = input()
product_3 = input()
print(product_1, product_2, product_3, sep = sep_str)
# Out:
# |
# Молоко
# Хлеб
# Сыр
# Молоко|Хлеб|Сыр

# %% [markdown]
# Задание №13

# %%
value_str = input()
print(int(float(value_str)))
# Out:
# 42.7
# 42

# %% [markdown]
# Задание №14

# %%
orders_yesterday = int(input())
plan = int(input())
abs_diff = abs(orders_yesterday-plan)
print('Абсолютное отклонение от плана равняется',abs_diff)
# Out:
# 10
# 20
# Абсолютное отклонение от плана равняется 10

# %% [markdown]
# Задание №15

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
e=int(input())
print('Наименьшее число =', min(a,b,c,d,e))
print('Наибольшее число =', max(a,b,c,d,e))
# Out:
# 6
# 15
# 25
# 1
# 6666666
# Наименьшее число = 1
# Наибольшее число = 6666666

# %% [markdown]
# Задание №16

# %%
first_name = input()
last_name = input()
print('Привет, ' + first_name + ' ' + last_name + '! Вы только что начали изучать Python')
# Out:
# Антон
# Иванов
# Привет, Антон Иванов! Вы только что начали изучать Python

# %% [markdown]
# Задание №17

# %%
str_1 = input()
str_2 = input()
print(str_1+' '+str_2)
# Out:
# «Каждый в этой стране должен научиться программировать,
# потому что это учит думать.»
# «Каждый в этой стране должен научиться программировать, потому что это учит думать.»

# %% [markdown]
# Задание №18

# %%
sum = float(input())
print(sum >=1000)
# Out:
# 1000.5
# True

# %% [markdown]
# Задание №19

# %%
age = int(input())
print(age>=18)
# Out:
# 16
# False

# %% [markdown]
# Задание №20

# %%
s = float(input())
v_1 = float(input())
v_2 = float(input())
t = s/(v_1+v_2)
print(t)
# Out:
# 500
# 50
# 70
# 4.166666666666667

# %% [markdown]
# Задание №21

# %%
a = float(input())
b = float(input())
s = a*b/2
print(s)
# Out:
# 443
# 390
# 86385.0

# %% [markdown]
# Задание №22

# %%
t_f = float(input())
t_c = (5/9)*(t_f-32)
print(t_c)
# Out:
# 450.55
# 232.5277777777778

# %% [markdown]
# Задание №23

# %%
revenue_str = float(input())
courier_name = input()
bonus = int(revenue_str*0.01)
report = 'Курьер '+ courier_name + ' получит бонус '+ str(bonus) + 'р.'
print(report)
# Out:
# 438746.78
# Влад
# Курьер Влад получит бонус 4387р.
